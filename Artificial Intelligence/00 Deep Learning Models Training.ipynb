# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
# import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix
import pickle


import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\YHLB2266\Données
# [nltk_data]     d'applications\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\YHLB2266\Données
# [nltk_data]     d'applications\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
 # Load data and set labels
data_positive = pd.read_csv('data/positive.csv', header=None)
column_labels = ['doc']
data_positive.columns = column_labels
data_positive['label'] = 1


# Display 5 random samples
data_positive.sample(5)
# Out:
#                                                      doc  label
# 33551   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      1
# 23590   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      1
# 14948   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      1
# 22620   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      1
# 35742   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      1

# %%
data_negative1 = pd.read_csv('data/negative-1.csv')
data_negative1.columns = column_labels
data_negative1['label'] = 0

data_negative1.sample(5)
# Out:
#                                                     doc  label
# 1628   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      0
# 2112   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      0
# 3672   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      0
# 424    NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      0
# 4161   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      0

# %%
data_negative2 = pd.read_csv('data/negative-2.csv')
data_negative2.columns = column_labels
data_negative2['label'] = 0

data_negative3 = pd.read_csv('data/negative-3.csv')
data_negative3.columns = column_labels
data_negative3['label'] = 0
 

data_negative5 = pd.read_csv('data/negative-5.csv')
data_negative5.columns = column_labels
data_negative5['label'] = 0


data_negative6 = pd.read_csv('data/negative-6.csv')
data_negative6.columns = column_labels
data_negative6['label'] = 0

data_negative7 = pd.read_csv('data/negative-7.csv')
data_negative7.columns = column_labels
data_negative7['label'] = 0

data_negative8 = pd.read_csv('data/negative-8.csv')
data_negative8.columns = column_labels
data_negative8['label'] = 0

data_negative9 = pd.read_csv('data/negative-9.csv')
data_negative9.columns = column_labels
data_negative9['label'] = 0

data_negative9.sample(5)
# Out:
#                                                     doc  label
# 4207   The tenuous colonialism bores interaction.The...      0
# 4802   The wary ecology encourages export.The ad hoc...      0
# 2880   The fierce cellar drinks catalogue.The bashfu...      0
# 1475   The supreme clover wrestles bosom.The shiveri...      0
# 4601   The super technician explains tool.The zany e...      0

# %%
# Concatenate complaining and non-complaining data
data = pd.concat([data_positive, data_negative1, data_negative2, data_negative3, data_negative5, data_negative6, data_negative7, data_negative8, data_negative9], axis=0).reset_index(drop=True)

# %%
# Display 5 random samples
data.sample(5)
# Out:
#                                                      doc  label
# 41804   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      0
# 69874  ET 193 ; EN FOI DE QUOI, LUI DELIVRONS LE PRES...      0
# 62732   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      0
# 19509   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      1
# 70784  FIXEES ADMIS pour souvent File ainsi contexte,...      0

# %%
data = data.sample(frac=1).reset_index(drop=True)

# %%
data.sample(5)
# Out:
#                                                      doc  label
# 47385   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      0
# 70994   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      0
# 12660   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      0
# 60392   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      1
# 61027   NOUS SOUSSIGNES, MEMBRES DU JURY DE L’EXAMEN ...      0

# %%
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC

# %%
df = pd.DataFrame(data)

# Tokenization and removing stop words and punctuation
stop_words = set(stopwords.words('french'))  # Assuming the documents are in French
punctuation = set(string.punctuation)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.model_selection import validation_curve

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Conv1D, MaxPooling1D, Bidirectional, Flatten
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import np_utils
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from string import punctuation

# Ensure you have the necessary NLTK datasets
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# WARNING:tensorflow:From C:\Users\YHLB2266\AppData\Local\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [nltk_data] Downloading package punkt to C:\Users\YHLB2266\Données
# [nltk_data]     d'applications\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\YHLB2266\Données
# [nltk_data]     d'applications\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Conv1D, MaxPooling1D, Bidirectional, Flatten
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import np_utils
from keras.utils import to_categorical

# %%
#Process the Doc
def preprocess_text(text):
    # Tokenize
    tokens = word_tokenize(text)
    # Remove stop words and punctuation
    return ' '.join([word for word in tokens if word not in stop_words and word not in punctuation])

df['processed_doc'] = df['doc'].apply(preprocess_text)

# %%
# Vectorization using TF-IDF
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df['processed_doc'])

# %%
# Tokenization
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['processed_doc'])
sequences = tokenizer.texts_to_sequences(df['processed_doc'])
word_index = tokenizer.word_index
print(f'Found {len(word_index)} unique tokens.')
# Out:
# Found 112250 unique tokens.

# %%
data = pad_sequences(sequences, maxlen=100)

# Label encoding
encoder = LabelEncoder()
encoded_labels = encoder.fit_transform(df['label'])
categorical_labels = to_categorical(encoded_labels)

# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(data, categorical_labels, test_size=0.2, random_state=42)

# %%
# Model Creation Function
def create_model(model_type):
    model = Sequential()
    model.add(Embedding(5000, 128, input_length=100))
    
    if model_type == 'SimpleNN':
        model.add(Flatten())
        model.add(Dense(128, activation='relu'))
    elif model_type == 'CNN':
        model.add(Conv1D(128, 5, activation='relu'))
        model.add(MaxPooling1D(5))
        model.add(Flatten())
    elif model_type == 'LSTM':
        model.add(LSTM(128))
    elif model_type == 'BiLSTM':
        model.add(Bidirectional(LSTM(128)))

    model.add(Dense(2, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Model Types
model_types = ['SimpleNN', 'CNN', 'LSTM', 'BiLSTM']
models = {t: create_model(t) for t in model_types}

# Train Models and Display Results
for name, model in models.items():
    print(f"Training {name} model...")
    history = model.fit(X_train, y_train, batch_size=32, epochs=10, verbose=1, validation_data=(X_test, y_test))
 
    
    
    # Prediction and Evaluation
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)
    accuracy = accuracy_score(y_test_classes, y_pred_classes)
    print(f'Accuracy for {name}: {accuracy:.4f}')

    plt.figure()
    # Confusion Matrix
    cm = confusion_matrix(y_test_classes, y_pred_classes)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    disp.ax_.set_title(f'Confusion Matrix for {name}') 
    
    
    plt.figure()
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'Learning Curve for {name}')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\YHLB2266\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\YHLB2266\AppData\Local\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\YHLB2266\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Training SimpleNN model...
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\YHLB2266\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\YHLB2266\AppData\Local\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 2000/2000 [==============================] - 20s 10ms/step - loss: 0.1177 - accuracy: 0.9626 - val_loss: 0.1105 - val_accuracy: 0.9681
# Epoch 2/10
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.1020 - accuracy: 0.9694 - val_loss: 0.1056 - val_accuracy: 0.9677
# Epoch 3/10
# 2000/2000 [==============================] - 19s 10ms/step - loss: 0.1007 - accuracy: 0.9697 - val_loss: 0.1053 - val_accuracy: 0.9679
# Epoch 4/10
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.0983 - accuracy: 0.9702 - val_loss: 0.1088 - val_accuracy: 0.9677
# Epoch 5/10
# 2000/2000 [==============================] - 21s 10ms/step - loss: 0.0967 - accuracy: 0.9706 - val_loss: 0.1085 - val_accuracy: 0.9676
# Epoch 6/10
# 2000/2000 [==============================] - 23s 12ms/step - loss: 0.0949 - accuracy: 0.9711 - val_loss: 0.1112 - val_accuracy: 0.9677
# Epoch 7/10
# 2000/2000 [==============================] - 21s 11ms/step - loss: 0.0925 - accuracy: 0.9715 - val_loss: 0.1108 - val_accuracy: 0.9673
# Epoch 8/10
# 2000/2000 [==============================] - 21s 11ms/step - loss: 0.0890 - accuracy: 0.9727 - val_loss: 0.1156 - val_accuracy: 0.9663
# Epoch 9/10
# 2000/2000 [==============================] - 21s 11ms/step - loss: 0.0860 - accuracy: 0.9737 - val_loss: 0.1208 - val_accuracy: 0.9659
# Epoch 10/10
# 2000/2000 [==============================] - 21s 11ms/step - loss: 0.0813 - accuracy: 0.9754 - val_loss: 0.1276 - val_accuracy: 0.9654
# 500/500 [==============================] - 2s 3ms/step
# Accuracy for SimpleNN: 0.9654
# Training CNN model...
# Epoch 1/10
# 2000/2000 [==============================] - 27s 13ms/step - loss: 0.1144 - accuracy: 0.9642 - val_loss: 0.1132 - val_accuracy: 0.9678
# Epoch 2/10
# 2000/2000 [==============================] - 26s 13ms/step - loss: 0.1010 - accuracy: 0.9694 - val_loss: 0.1041 - val_accuracy: 0.9679
# Epoch 3/10
# 2000/2000 [==============================] - 26s 13ms/step - loss: 0.0996 - accuracy: 0.9693 - val_loss: 0.1049 - val_accuracy: 0.9677
# Epoch 4/10
# 2000/2000 [==============================] - 27s 13ms/step - loss: 0.0988 - accuracy: 0.9699 - val_loss: 0.1071 - val_accuracy: 0.9677
# Epoch 5/10
# 2000/2000 [==============================] - 27s 13ms/step - loss: 0.0981 - accuracy: 0.9699 - val_loss: 0.1048 - val_accuracy: 0.9676
# Epoch 6/10
# 2000/2000 [==============================] - 27s 13ms/step - loss: 0.0962 - accuracy: 0.9702 - val_loss: 0.1084 - val_accuracy: 0.9669
# Epoch 7/10
# 2000/2000 [==============================] - 25s 13ms/step - loss: 0.0952 - accuracy: 0.9710 - val_loss: 0.1098 - val_accuracy: 0.9677
# Epoch 8/10
# 2000/2000 [==============================] - 27s 13ms/step - loss: 0.0930 - accuracy: 0.9711 - val_loss: 0.1093 - val_accuracy: 0.9678
# Epoch 9/10
# 2000/2000 [==============================] - 26s 13ms/step - loss: 0.0912 - accuracy: 0.9715 - val_loss: 0.1121 - val_accuracy: 0.9662
# Epoch 10/10
# 2000/2000 [==============================] - 26s 13ms/step - loss: 0.0887 - accuracy: 0.9721 - val_loss: 0.1167 - val_accuracy: 0.9660
# 500/500 [==============================] - 3s 5ms/step
# Accuracy for CNN: 0.9660
# Training LSTM model...
# Epoch 1/10
# 2000/2000 [==============================] - 117s 58ms/step - loss: 0.2920 - accuracy: 0.8808 - val_loss: 0.3623 - val_accuracy: 0.8419
# Epoch 2/10
# 2000/2000 [==============================] - 120s 60ms/step - loss: 0.1410 - accuracy: 0.9547 - val_loss: 0.1107 - val_accuracy: 0.9666
# Epoch 3/10
# 2000/2000 [==============================] - 118s 59ms/step - loss: 0.1136 - accuracy: 0.9659 - val_loss: 0.1110 - val_accuracy: 0.9662
# Epoch 4/10
# 2000/2000 [==============================] - 120s 60ms/step - loss: 0.1103 - accuracy: 0.9668 - val_loss: 0.1073 - val_accuracy: 0.9664
# Epoch 5/10
# 2000/2000 [==============================] - 123s 61ms/step - loss: 0.1095 - accuracy: 0.9673 - val_loss: 0.1117 - val_accuracy: 0.9658
# Epoch 6/10
# 2000/2000 [==============================] - 124s 62ms/step - loss: 0.1057 - accuracy: 0.9682 - val_loss: 0.1085 - val_accuracy: 0.9674
# Epoch 7/10
# 2000/2000 [==============================] - 118s 59ms/step - loss: 0.1067 - accuracy: 0.9677 - val_loss: 0.1137 - val_accuracy: 0.9662
# Epoch 8/10
# 2000/2000 [==============================] - 116s 58ms/step - loss: 0.1044 - accuracy: 0.9690 - val_loss: 0.1085 - val_accuracy: 0.9667
# Epoch 9/10
# 2000/2000 [==============================] - 123s 62ms/step - loss: 0.1037 - accuracy: 0.9685 - val_loss: 0.1091 - val_accuracy: 0.9667
# Epoch 10/10
# 2000/2000 [==============================] - 131s 65ms/step - loss: 0.1030 - accuracy: 0.9693 - val_loss: 0.1090 - val_accuracy: 0.9672
# 500/500 [==============================] - 12s 22ms/step
# Accuracy for LSTM: 0.9672
# Training BiLSTM model...
# Epoch 1/10
# 2000/2000 [==============================] - 153s 74ms/step - loss: 0.1675 - accuracy: 0.9409 - val_loss: 0.1427 - val_accuracy: 0.9535
# Epoch 2/10
# 2000/2000 [==============================] - 140s 70ms/step - loss: 0.1317 - accuracy: 0.9577 - val_loss: 0.1081 - val_accuracy: 0.9681
# Epoch 3/10
# 2000/2000 [==============================] - 143s 72ms/step - loss: 0.1036 - accuracy: 0.9688 - val_loss: 0.1097 - val_accuracy: 0.9681
# Epoch 4/10
# 2000/2000 [==============================] - 151s 76ms/step - loss: 0.1067 - accuracy: 0.9673 - val_loss: 0.1067 - val_accuracy: 0.9675
# Epoch 5/10
# 2000/2000 [==============================] - 156s 78ms/step - loss: 0.1011 - accuracy: 0.9688 - val_loss: 0.1056 - val_accuracy: 0.9672
# Epoch 6/10
# 2000/2000 [==============================] - 161s 81ms/step - loss: 0.0998 - accuracy: 0.9691 - val_loss: 0.1079 - val_accuracy: 0.9679
# Epoch 7/10
# 2000/2000 [==============================] - 158s 79ms/step - loss: 0.0986 - accuracy: 0.9698 - val_loss: 0.1067 - val_accuracy: 0.9672
# Epoch 8/10
# 2000/2000 [==============================] - 154s 77ms/step - loss: 0.0992 - accuracy: 0.9694 - val_loss: 0.1239 - val_accuracy: 0.9581
# Epoch 9/10
# 2000/2000 [==============================] - 154s 77ms/step - loss: 0.0973 - accuracy: 0.9701 - val_loss: 0.1099 - val_accuracy: 0.9674
# Epoch 10/10
# 2000/2000 [==============================] - 149s 75ms/step - loss: 0.0970 - accuracy: 0.9704 - val_loss: 0.1084 - val_accuracy: 0.9677
# 500/500 [==============================] - 13s 23ms/step
# Accuracy for BiLSTM: 0.9677
